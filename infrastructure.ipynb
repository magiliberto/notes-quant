# %% [markdown]
# # Infrastructure
#
# Types of technologies that help with Python deployment:
# * Package managers (pip & conda)
# * Virtual enviroment managers (virtualenv & conda)
# * Docker containers
# * Cloud Instances (AWS, DigitalOcean, Linode)
#
# Anaconda - Miniconda: Python distributions including
# * Python
# * Conda package manager
# * Conda virtual enviroments manager
#
# ## Cloud Instances - DigitalOcean
#
# Required files:
# * RSA Public and Private Keys
# * SSH Keys
# * Jupyter Notebook Configuration File
# * Installation Script for Python and Jupyter
# * Script to Orchestrate the Droplet Setup
#
# ### RSA Public and Private Keys
# files: cert.pem cert.key
#
# openssl req -x509 -nodes -days 365 -newkey rsa:1024 -out cert.pem -keyout cert.key
# AR
# Buenos-Aires
#
#
# MG
# mauricio.giliberto@gmail.com
#
# ### SSH Keys
# source: https://docs.gitlab.com/ee/user/ssh.html#ed25519-ssh-keys
# files:
#
# ssh-keygen -t ed25519 -C "mauricio.giliberto@gmail.com"
# Generating public/private ed25519 key pair.
# Enter file in which to save the key (/home/user/.ssh/id_ed25519_DO_test):
#
# ### Jupyter Notebook Configuration File
# files: jupyter_notebook_config.py
#
# ipython
# from notebook.auth import passwd
#
# passwd('123', algorithm="sha1")
# exit
#
# ### Installation Script for Python and Jupyter
# files: install.sh
#
# ### Script to Orchestrate the Droplet Setup
# files: setup.sh
#
#
# ssh root@<ip>
